# %% [markdown]
# <a href="https://colab.research.google.com/github/vyshnkb/DigitalQueueSystem/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a=np.array([10,20,30,40])
print(a)
# Out:
# [10 20 30 40]

# %%
b=np.array([[1,2,3],[4,5,6]])
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
a=np.array([[1,2,3],[4,5,6]])
print(a.shape)
# Out:
# (2, 3)

# %%
a=np.array([[1,2,3],[4,5,6]])
print(a.ndim)
# Out:
# 2

# %%
a=np.zeros(5)
print(a)
# Out:
# [0. 0. 0. 0. 0.]

# %%
a=np.ones(5)
print(a)
# Out:
# [1. 1. 1. 1. 1.]

# %%
a=np.arange(1,10,2)
print(a)
# Out:
# [1 3 5 7 9]

# %%
a=np.array([1,2,3,4])
print(a+5)
# Out:
# [6 7 8 9]

# %%
print(a*2)
# Out:
# [2 4 6 8]

# %%
a=np.array([10,20,30,40])
print(np.sum(a))
# Out:
# 100

# %%
print(np.mean(a))
# Out:
# 25.0

# %%
print(np.max(a))
print(np.min(a))
# Out:
# 40
# 10

# %%
print(np.std(a))
# Out:
# 11.180339887498949

# %%
print(a[0])
print(a[2])
# Out:
# 10
# 30

# %%
print(a[1:4])
# Out:
# [20 30 40]

# %%
import pandas as pd
data={'Name':['Anu','Rahul','Meera'],'Marks':[85,90,88]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks
# 0    Anu     85
# 1  Rahul     90
# 2  Meera     88

# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
sales=[100,120,140,130,160]
plt.plot(days,sales)
plt.show()

# %%
plt.title("Daily Sales")
# Out:
# Text(0.5, 1.0, 'Daily Sales')

# %%
plt.xlabel("Days")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
sjects=["Maths","Physivs","Chemistry"]
markubs=[80,92,85]
plt.bar(subjects,marks)
plt.title("Marks in subjects")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
sjects=["Maths","Physivs","Chemistry"]
markubs=[80,92,85]
plt.barh(subjects,marks)
plt.show()

# %%
marks=[40,30,20,10]
subjects=["maths","physics","chemistry","English"]
plt.pie(marks,labels=subjects)
plt.show()

# %%
hours=[1,2,3,4,5]
marks=[40,50,60,70,80]
plt.scatter(hours,marks)
plt.xlabel("hour studied")
plt.ylabel("marks")
plt.show()

# %%
marks=[45,50,60,70,72,75,80,82,90,95]
plt.hist(marks)
plt.show()

# %%
x=[1,2,3,4]
y1=[10,20,30,40]
y2=[15,25,35,45]
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
plt.plot([1,2,3],[10,20,30])
plt.savefig("graph.png")
