# %% [markdown]
# <a href="https://colab.research.google.com/github/vyshnkb/DigitalQueueSystem/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("this is my first ml lab)
# Out:
# this is my first ml lab

# %%
import numpy as np
a = np.array([10,20,30,40])
print(a)
# Out:
# [10 20 30 40]

# %%
import numpy as np
a = np.array([
[1,2,3],
[4,5,6]
])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
a = np.array([
[1,2,3],
[4,5,6]
])
print(a.shape)
# Out:
# (2, 3)

# %%
import numpy as np
a = np.array([[1,2,3],[4,5,6]])
print(a.ndim)
# Out:
# 2

# %%
import numpy as np
a = np.zeros(5)
print(a)
# Out:
# [0. 0. 0. 0. 0.]

# %%
import numpy as np
a = np.ones(5)
print(a)
# Out:
# [1. 1. 1. 1. 1.]

# %%
import numpy as np
a = np.arrange(1,10,2)
print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1560/4264592586.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 a = np.arrange(1,10,2)
#       3 print(a)
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     408             return char.chararray
#     409
# --> 410         raise AttributeError("module {!r} has no attribute "
#     411                              "{!r}".format(__name__, attr))
#     412
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
import numpy as np
a = np.arange(,10,2)
print(a)
# Out:
#   File "/tmp/ipykernel_1560/1927119281.py", line 2
#     a = np.arange(,10,2)
#                   ^
# SyntaxError: invalid syntax

# %%
import numpy as np
a = np.arange(1,10,2)
print(a)
# Out:
# [1 3 5 7 9]

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a + 5)
# Out:
# [6 7 8 9]

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a * 2)
# Out:
# [2 4 6 8]

# %%
import numpy as np
a = np.array([10,20,30,40])
print(np.sum(a))
# Out:
# 100

# %%
import numpy as np
a= np.array([10,20,30,40])
print(np.mean(a))
# Out:
# 25.0

# %%
import numpy as np
a = np.array([10,20,30,40])
print(np.max(a))
print(np.min(a))
# Out:
# 40
# 10

# %%
import numpy as np
a = np.array([10,20,30,40])
print(np.std(a))
# Out:
# 11.180339887498949

# %%
import numpy as np
a = np.array([10,20,30,40])
print(a[0])
print(a[10])
# Out:
# 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1560/506618683.py in <cell line: 0>()
#       2 a = np.array([10,20,30,40])
#       3 print(a[0])
# ----> 4 print(a[10])
#
# IndexError: index 10 is out of bounds for axis 0 with size 4

# %%
import numpy as np
a = np.array([10,20,30,40])
print(a[0])
print(a[2])
# Out:
# 10
# 30

# %%
import numpy as np
a = np.array([10,20,30,40,50])
print(a[1:4])
# Out:
# [20 30 40]

# %%
import matplotlib.pylot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1560/3792379548.py in <cell line: 0>()
# ----> 1 import matplotlib.pylot as plt
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
days = [1,2,3,4,5]
sales = [100,200,140,130,160]
plt.plot(days,sales)
plt.show()

# %%
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.xlabel("Label")
plt.ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %%
import matplotlib.pyplot as plt
subjects = ["maths",
             "physics",
              "chemistry"]
marks = [80,92,75]
plt.bar(subjects,marks)
plt.title("marks in subjects")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.show()

# %%
import matplotlib.pyplot as plt
marks = [40,30,20,10]
subjects = ["maths",
             "physics",
              "chemistry",
               "english"]
plt.pie(marks,
        labels=subjects)
plt.show()

# %%
import matplotlib.pyplot as plt
marks = [45,50,60,70,72,
         75,80,82,90,95]
plt.hist(marks)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y1 = [10,20,30,40]
y2 = [15,25,35,45]
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
plt.plot([1,2,3],[10,20,30])
plt.savefig("graph.png")

# %%
import pandas as pd
